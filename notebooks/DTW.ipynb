# %%
# %matplotlib inline
# %load_ext version_information
import matplotlib as mpl
mpl.rcParams["figure.figsize"] = (16,9)
import seaborn
# Out:
# The version_information extension is already loaded. To reload it, use:
#   %reload_ext version_information

# %% [markdown]
# # Dynamic time warping

# %% [markdown]
# Nadpis máme nahoře $\uparrow$, teď jak bych to přeložil do češtiny? První co mě napadlo, bylo podívat se na Google translátor a při té příležitosti jsem se zkusil na stejné heslo zeptat i WolframAlphy, jaká byla její odpověď vidíte na vloženém snímku níže $\downarrow$.

# %%
from IPython.display import IFrame
IFrame("http://www.wolframalpha.com/input/?i=dynamic+time+warping", width=960, height=480)
# Out:
#         <iframe
#             width="960"
#             height="480"
#             src="http://www.wolframalpha.com/input/?i=dynamic+time+warping"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Nic. Možná, kdybych ji nechal svůj e-mail, nebo ji zaplatil, dozvěděl bych se více. Ale to je proti naší filozofii svobodného přístupu k informacím. Jako podmínkou naprosto nutnou pro reprodukovatelnou vědu. Proto se raději obrátím na Wiki, kde už se dočtu alespoň nějaké zajímavé informace. Slova, kterým nerozumím, si rozkliknu a pseudokód přepíšu do řeči jazyka Python.

# %%
IFrame("https://en.wikipedia.org/wiki/Dynamic_time_warping", width=960, height=480)
# Out:
#         <iframe
#             width="960"
#             height="480"
#             src="https://en.wikipedia.org/wiki/Dynamic_time_warping"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #1 Teď by se mi vážně hodil nějaký konvertor Wikipedie do Jupyter (wiki2py) notebooku, implementovaný pochopitelně v Jupyter Notebooku samotném ;-)
#
# *Představoval bych si to asi tak*
#
# * DO prvního pole se vloží Heslo z Wiki stránky a stiskne se přiložené tlačítko
#
# <button type="button" class="btn btn-default btn-lg">
#   <span class="glyphicon glyphicon-play" aria-hidden="true"> Run</span>
# </button>
#
# <!-- funkčnost předvedu v prezentaci o gitu, až ji budu rozšiřovat o bootstrapí blbosti -->
#
# * PRO zadané URL konvertuj zdrojový kód `wiki` do formátu `markdown`, respektive `JSON`
#
#  - rozlož jej na jednotlivé části
#  - a ty převeď na vhodné buňky v tomto notebooku
#
# ** Odevzdávejte ideálně průběžně během semestru počínaje od teď, zásadně pomocí `git`u, ať se k tomu můžeme i my průběžně vyjadřovat. A pokud možno i ve formě dávkově spustitelného skriptu, exportovaného z počátečního notebooku. Dostatečné množství srozumitelných komentářů nechť je považováno za podmínku nutnou, nikoliv postačující.**

# %%
# %run -t ../scripts/dtw.py
# Out:
# edist = 1.592565002417828
# dtw = 1.8351001281383752
# lcss = 0.4444444444444444
# IPython CPU timings (estimated):
#   User   :       0.55 s.
#   System :       0.01 s.
# Wall time:       0.57 s.

# %%
# %version_information numpy, scipy, matplotlib, seaborn
# Out:
# Software versions
# Python 3.5.1 64bit [GCC 5.2.0]
# IPython 4.0.0
# OS Linux 4.2.5 1 ARCH x86_64 with arch
# numpy 1.10.2
# scipy 0.16.1
# matplotlib 1.5.0
# seaborn 0.6.0
# Sat Dec 19 04:51:04 2015 CET
